# %% [markdown]
# # Special Relativity vs Classical Mechanics
# ---
# ![special_relativity](figs/special_relativity.png)

# %% [markdown]
# # General Relativity and Strong gravitational fields
#    ![wave propagation](figs/light_travelling.png)

# %% [markdown]
# # Light is a wave or a particle
#    ![wave propagation](figs/photoelectric_effect.png)

# %%
# The photoelectric effect
from IPython.display import YouTubeVideo
YouTubeVideo('SgXW4foFGpw', width=1100, height=500, allow_autoplay=True, start=1)

# %%
# Rutherford experiment and the Nuclei
from IPython.display import YouTubeVideo

YouTubeVideo('fLFXDdnJN5U', width=1100, height=500, allow_autoplay=True, start=45)

# %%
# Atomic Models
from IPython.display import YouTubeVideo

YouTubeVideo('Mxow_MvhZX0', width=1200, height=500, allow_autoplay=True, start=5)

# %%
# Thomas Young double slit experiment
from IPython.display import YouTubeVideo

YouTubeVideo('O2klAr6Mmek', width=1200, height=400, allow_autoplay=True, start=140)

# %%
# Particles behaving as waves
from IPython.display import YouTubeVideo

YouTubeVideo('NvzSLByrw4Q', width=1200, height=500, allow_autoplay=True, start=50)

# %%
# Particles behaving as waves
from IPython.display import YouTubeVideo

YouTubeVideo('mL63s4QqVPc', width=800, height=300, allow_autoplay=True, start=1)

# %%
# Huygens principle of light propagation
from IPython.display import YouTubeVideo

YouTubeVideo('mL63s4QqVPc', width=800, height=300, allow_autoplay=True, start=1)

# %% [markdown]
# ## Compton scattering
# ![special_relativity](figs/compton_scattering.png)

# %%
# The end!!
